# %%
import pandas as pd
import numpy as np
df = pd.read_csv('watches.csv')

# %%
df
# Out:
#                                                  title   price rating  \
# 0    USM ID116 Smart Watch Smart Bracelet Fitness T...     329    4.3
# 1    boAt Flash Edition Smart Watch with Activity T...   1,199    4.0
# 2    Noise ColorFit Pulse Grand Smart Watch with 1....   1,299    4.0
# 3    boAt Xtend Smartwatch Batman Edition with Alex...   1,299    4.2
# 4     Krishna Analog Analog Watch - for Boys & Girls       119    5.0
# ..                                                 ...     ...    ...
# 301  Watches: The History of Time: Signature Timepi...       0    3.6
# 302  Pebble Cosmos Endure 1.46" AMOLED Always-On Di...   4,499    4.4
# 303                        Analog Dial Women's Watch    2,389.    4.3
# 304  Trendies Analog Black Dial Men's Watch-NL38048...   2,295    4.3
# 305        Analog Silver Dial Men's Watch-TW00ZR286E     1,812    4.4
#
#         oprice              brand
# 0         ₹329                USM
# 1       ₹1,199               boAt
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                                                  title   price rating  \
# 0    USM ID116 Smart Watch Smart Bracelet Fitness T...     329    4.3
# 1    boAt Flash Edition Smart Watch with Activity T...   1,199    4.0
# 2    Noise ColorFit Pulse Grand Smart Watch with 1....   1,299    4.0
# 3    boAt Xtend Smartwatch Batman Edition with Alex...   1,299    4.2
# 4     Krishna Analog Analog Watch - for Boys & Girls       119    5.0
# ..                                                 ...     ...    ...
# 301  Watches: The History of Time: Signature Timepi...       0    3.6
# 302  Pebble Cosmos Endure 1.46" AMOLED Always-On Di...   4,499    4.4
# 303                        Analog Dial Women's Watch    2,389.    4.3
# 304  Trendies Analog Black Dial Men's Watch-NL38048...   2,295    4.3
# 305        Analog Silver Dial Men's Watch-TW00ZR286E     1,812    4.4
#
#         oprice              brand
# 0         ₹329                USM
# ...
